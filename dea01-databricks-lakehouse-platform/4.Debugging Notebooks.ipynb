# %% [markdown]
# # Debugging Databricks Notebooks
# > Enable Debugger: Settings -> Developer -> Enable Python notebook interacive debugger. <br>
# > Supported Runtime - 13.3 LTS or Higher <br>
# > Supported Languafes - Only Python at the moment

# %% [markdown]
# ## Demo 1
#
# Demostrate
#   1. Breackpoints
#   2. Step throungh code line by line
#   3. Variable Explorer
#   4. Debug Console

# %%
# calculate the final price of an item and print the finaçl total 

item_price = 120.00
tax_rate = 20
discount = 10.00

# 1. Calculate the tac to ve applied 
tax = item_price * (tax_rate / 100)

# 2. Apply tax to the item price 
item_price_with_tax = item_price + tax

# 3. Apply the flat discount to the item price 
final_price = item_price_with_tax - discount

# Final Print 
print(f'Final price: {final_price:.2f}')

# %% [markdown]
# # Demo 2
# Demonstrate Step in and Step Out

# %%
def calculate_final_price(item_price, tac_rate, discount):
    # 1. Calculate the tax to be applied
    tax = item_price * (tax_rate / 100)

    # 2. Apply tax to the item price
    item_price_with_tax = item_price - tax

    # 3. Apply the flat discount to the item price
    final_price = item_price_with_tax - discount

    return final_price

# %%
# Main program
item_price = 120.00
tax_rate = 20
discount = 10.00

final_price = calculate_final_price(item_price, tax_rate, discount)

print(f'Final price: {final_price:.2f}')
