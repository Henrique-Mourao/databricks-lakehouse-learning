# %% [markdown]
# # Databricks Utilities
# - File system utilities
# - Secrets Utilities
# - Widget Utilities
# - Notebook Workflow Utilities

# %% [markdown]
# ## File system utilities

# %%
# %fs ls

# %%
display(dbutils.fs.ls('/'))

# %%
# %fs ls dbfs:/databricks-datasets/

# %%
items = dbutils.fs.ls('/databricks-datasets/')

# %%
# Count folders and files using list comprehensions
folder_count = len([item for item in items if item.isDir()])
file_count = len([item for item in items if not item.isDir()])
# Display the results 
print(f"Total Folders: {folder_count}")
print(f"Total Files: {file_count}")

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.fs.help('cp')
