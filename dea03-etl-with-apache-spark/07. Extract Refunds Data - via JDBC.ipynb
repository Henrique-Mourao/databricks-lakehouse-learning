# %% [markdown]
# <b>Extract Data From the Returns SQL Table
# 1. Create Bronze Schema in Hive Metastore
# 2. Create External Table

# %% [markdown]
# <b>1. Create Bronze Schema in Hive Metastore

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS hive_metastore.bronze;

# %% [markdown]
# <b>2. Create External Table

# %%
# %sql
CREATE TABLE IF NOT EXISTS hive_metastore.bronze.refunds 
USING JBDC 
OPTIONS ( 
  url "jdbc:mysql://database-1.cqzqzqzqzqzq.us-west-2.rds.amazonaws.com:3306", 
  dbtable "payments", 
  user "herique",
  password "12345678",
);

# %%
# %sql
SELECT * FROM hive_metastore.bronze.refunds;
