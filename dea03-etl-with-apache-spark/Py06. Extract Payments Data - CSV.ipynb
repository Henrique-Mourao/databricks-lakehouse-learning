# %% [markdown]
# <b> Extract Data From the Payments Files
# 1. Read Payments Files
# 2. Create Payments table in Bronze Schema

# %% [markdown]
# <b> 1. List the file from Payment Folder

# %%
# %fs ls '/Volumes/gizmobox/landing/external_data/payments/'

# %% [markdown]
# <b> 2. Create External Table

# %%
payments_schema = 'payment_id INTEGER, order_id INTEGER, payment_timestamp TIMESTAMP, payment_status INTEGER, payment_method STRING'

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, TimestampType
py_payments_schema = StructType([
    StructField('payment_id', IntegerType()),
    StructField('order_id', IntegerType()),
    StructField('payment_timestamp', TimestampType()),
    StructField('payment_status', IntegerType()),
    StructField('payment_method', StringType())
])

# %%
df = (
    spark.read.format('csv')
            .option('delimiter', ',')
            .schema(payments_schema)
            .load('dbfs:/Volumes/gizmobox/landing/external_data/payments/payments_2024_10.csv')

)
display(df)

# %% [markdown]
# <b> 3. Demonstrate the effect of Adding/ Updating/ Deleting files

# %%
df.writeTo('gizmobox.bronze.py_payments').createOrReplace()

# %%
# %sql
SELECT * FROM gizmobox.bronze.py_payments;
