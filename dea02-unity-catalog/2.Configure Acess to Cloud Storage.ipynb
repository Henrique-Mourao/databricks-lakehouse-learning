# %% [markdown]
# # Configure Acess to Cloud Storage via Unity Catalog
#
# ### Access Cloud Storage

# %%
# %sql
# %fs ls 'abfss://<EMAIL>@<EMAIL>.dfs.core.windows.'

# %% [markdown]
# ## Create External Location

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS cloud_storage
  URL 'abfss://<EMAIL>@<EMAIL>.dfs.core.windows.'
  WITH (STORAGE CREDENTIAL cloud_storage)
  COMMENT 'External Location for Demo Purposes'
